# %% [markdown]
# <a href="https://colab.research.google.com/github/suhani2010/Inventory_management01/blob/main/AddProduct.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###**ADDING MODULE**
#
# 1. ADMIN CAN ADD A NEW PRODUCT
# 2. ADMIN CAN ADD AN EXISTING PRODUCT
# 3. ADMIN CAN DELETE A PRODUCT

# %%
import json
fd = open("record.json",'r')
r = fd.read()
fd.close()

record = json.loads(r)

# %%
record
# Out:
# {'1002': {'Category': 'Beverages',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Cola',
#   'pr': 800,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1003': {'Category': 'Chinese',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Noodles',
#   'pr': 85,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1004': {'Category': 'Pizza',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'margherita',
#   'pr': 5,
#   'qn': 1000,
#   'ratings': 'Unrated'},
#  '1005': {'Category': 'Fastfood',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Sandwich',
#   'pr': 20,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1006': {'Category': 'Fastfood',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Burger',
#   'pr': 50000,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1007': {'Category': 'Pizza',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Cheese and corn pizza',
#   'pr': 1500,
#   'qn': 0,
#   'ratings': 'Unrated'},
#  '1008': {'Category': 'Deserts',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Icecream',
#   'pr': 599,
#   'qn': 5,
#   'ratings': 'Unrated'},
#  '1009': {'Category': 'Chinese',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Manchurian',
#   'pr': 1999,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1010': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 10,
#   'name': 'mojito',
#   'pr': 400,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1011': {'Times_purchased': 0,
#   'category': 'Chinese',
#   'discount': 25,
#   'name': 'whitw sause pasta',
#   'pr': 500,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1012': {'Times_purchased': 0,
#   'category': 'Deserts',
#   'discount': 23,
#   'name': 'Ras Malai',
#   'pr': 250,
#   'qn': 30,
#   'ratings': 'Unrated'},
#  '1013': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 10,
#   'name': 'Cheese Chutney Sandwich',
#   'pr': 200,
#   'qn': 60,
#   'ratings': 'Unrated'},
#  '1014': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 5,
#   'name': 'Pepsi',
#   'pr': 60,
#   'qn': 80,
#   'ratings': 'Unrated'},
#  '1015': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 20,
#   'name': 'Peppy Paneer',
#   'pr': 450,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1016': {'Times_purchased': 0,
#   'category': 'Deserts',
#   'discount': 10,
#   'name': 'Gulab Jaamun',
#   'pr': 300,
#   'qn': 20,
#   'ratings': 'Unrated'},
#  '1017': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 20,
#   'name': 'pav bhaji',
#   'pr': 400,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1018': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 0,
#   'name': 'kachori',
#   'pr': 20,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1019': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 20,
#   'name': 'Mexican Pizza',
#   'pr': 600,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1020': {'Times_purchased': 0,
#   'category': 'Desserts',
#   'discount': 5,
#   'name': 'Cornetto Icecream',
#   'pr': 100,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1021': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 5,
#   'name': 'Cold Coffee',
#   'pr': 200,
#   'qn': 30,
#   'ratings': 'Unrated'},
#  '1023': {'Times_purchased': 0,
#   'category': 'Bevarages',
#   'discount': 0,
#   'name': 'Tea',
#   'pr': 20,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1024': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 15,
#   'name': 'Cheese burst Sandwich',
#   'pr': 500,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1025': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 10,
#   'name': 'Red sauce pasta',
#   'pr': 300,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1026': {'Times_purchased': 0,
#   'category': 'Chinese',
#   'discount': 10,
#   'name': 'Sizzler',
#   'pr': 800,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1027': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 10,
#   'name': 'Paneer and Onion Pizza',
#   'pr': 500,
#   'qn': 12,
#   'ratings': 'Unrated'},
#  '1028': {'Times_purchased': 0,
#   'category': 'Desserts',
#   'discount': 10,
#   'name': 'Bengalli sweet',
#   'pr': 480,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1029': {'Times_purchased': 0,
#   'category': 'Chinese',
#   'discount': 15,
#   'name': 'chinese bhel',
#   'pr': 380,
#   'qn': 20,
#   'ratings': 'Unrated'},
#  '1030': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 10,
#   'name': 'Kitkat shake',
#   'pr': 250,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1031': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 0,
#   'name': 'Chinese pattis',
#   'pr': 25,
#   'qn': 25,
#   'ratings': 'Unrated'},
#  '1032': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 0,
#   'name': 'vadapav',
#   'pr': 50,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1033': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 10,
#   'name': 'Cheese Dosa',
#   'pr': 250,
#   'qn': 30,
#   'ratings': 'Unrated'},
#  '1034': {'Times_purchased': 0,
#   'category': 'Desserts',
#   'discount': 5,
#   'name': 'Belgium truffle',
#   'pr': 280,
#   'qn': 20,
#   'ratings': 'Unrated'}}

# %% [markdown]
# ###Adding a New or Existing Item into Inventory

# %%
prod_id = str(input("Enter product id:"))
category = str(input("Enter category:"))
name = str(input("Enter name:"))
pr = int(input("Enter price:"))
qn = int(input("Enter quantity:"))
discount =int(input("Enter discount:"))

for id in record:
  if id==prod_id:
    record[id]['qn']=record[id]['qn']+qn
    record[id]['pr']=pr
    record[id]['discount']=discount
    break
else:
  record[prod_id] = {'name': name, 'pr': pr, 'qn': qn, 'category':category, 'discount':discount, 'ratings':'Unrated','Times_purchased':0 ,'Times_rated':0}

js = json.dumps(record)

fd = open("record.json",'w')
fd.write(js)
fd.close()
# Out:
# Enter product id:1041
# Enter category:Desserts
# Enter name:rabri
# Enter price:400
# Enter quantity:20
# Enter discount:10

# %%
record
# Out:
# {'1002': {'Category': 'Beverages',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Cola',
#   'pr': 800,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1003': {'Category': 'Chinese',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Noodles',
#   'pr': 85,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1004': {'Category': 'Pizza',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'margherita',
#   'pr': 5,
#   'qn': 1000,
#   'ratings': 'Unrated'},
#  '1005': {'Category': 'Fastfood',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Sandwich',
#   'pr': 20,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1006': {'Category': 'Fastfood',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Burger',
#   'pr': 50000,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1007': {'Category': 'Pizza',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Cheese and corn pizza',
#   'pr': 1500,
#   'qn': 0,
#   'ratings': 'Unrated'},
#  '1008': {'Category': 'Deserts',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Icecream',
#   'pr': 599,
#   'qn': 5,
#   'ratings': 'Unrated'},
#  '1009': {'Category': 'Chinese',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Manchurian',
#   'pr': 1999,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1010': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 10,
#   'name': 'mojito',
#   'pr': 400,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1011': {'Times_purchased': 0,
#   'category': 'Chinese',
#   'discount': 25,
#   'name': 'whitw sause pasta',
#   'pr': 500,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1012': {'Times_purchased': 0,
#   'category': 'Deserts',
#   'discount': 23,
#   'name': 'Ras Malai',
#   'pr': 250,
#   'qn': 30,
#   'ratings': 'Unrated'},
#  '1013': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 10,
#   'name': 'Cheese Chutney Sandwich',
#   'pr': 200,
#   'qn': 60,
#   'ratings': 'Unrated'},
#  '1014': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 5,
#   'name': 'Pepsi',
#   'pr': 60,
#   'qn': 80,
#   'ratings': 'Unrated'},
#  '1015': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 20,
#   'name': 'Peppy Paneer',
#   'pr': 450,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1016': {'Times_purchased': 0,
#   'category': 'Deserts',
#   'discount': 10,
#   'name': 'Gulab Jaamun',
#   'pr': 300,
#   'qn': 20,
#   'ratings': 'Unrated'},
#  '1017': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 20,
#   'name': 'pav bhaji',
#   'pr': 400,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1018': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 0,
#   'name': 'kachori',
#   'pr': 20,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1019': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 20,
#   'name': 'Mexican Pizza',
#   'pr': 600,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1020': {'Times_purchased': 0,
#   'category': 'Desserts',
#   'discount': 5,
#   'name': 'Cornetto Icecream',
#   'pr': 100,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1021': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 5,
#   'name': 'Cold Coffee',
#   'pr': 200,
#   'qn': 30,
#   'ratings': 'Unrated'},
#  '1023': {'Times_purchased': 0,
#   'category': 'Bevarages',
#   'discount': 0,
#   'name': 'Tea',
#   'pr': 20,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1024': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 15,
#   'name': 'Cheese burst Sandwich',
#   'pr': 500,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1025': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 10,
#   'name': 'Red sauce pasta',
#   'pr': 300,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1026': {'Times_purchased': 0,
#   'category': 'Chinese',
#   'discount': 10,
#   'name': 'Sizzler',
#   'pr': 800,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1027': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 10,
#   'name': 'Paneer and Onion Pizza',
#   'pr': 500,
#   'qn': 12,
#   'ratings': 'Unrated'},
#  '1028': {'Times_purchased': 0,
#   'category': 'Desserts',
#   'discount': 10,
#   'name': 'Bengalli sweet',
#   'pr': 480,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1029': {'Times_purchased': 0,
#   'category': 'Chinese',
#   'discount': 15,
#   'name': 'chinese bhel',
#   'pr': 380,
#   'qn': 20,
#   'ratings': 'Unrated'},
#  '1030': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 10,
#   'name': 'Kitkat shake',
#   'pr': 250,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1031': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 0,
#   'name': 'Chinese pattis',
#   'pr': 25,
#   'qn': 25,
#   'ratings': 'Unrated'},
#  '1032': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 0,
#   'name': 'vadapav',
#   'pr': 50,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1033': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 10,
#   'name': 'Cheese Dosa',
#   'pr': 250,
#   'qn': 30,
#   'ratings': 'Unrated'},
#  '1034': {'Times_purchased': 0,
#   'category': 'Desserts',
#   'discount': 10,
#   'name': 'Belgium truffle',
#   'pr': 200,
#   'qn': 120,
#   'ratings': 'Unrated'},
#  '1035': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 5,
#   'name': 'Frankie',
#   'pr': 120,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1036': {'Times_purchased': 0,
#   'category': 'Deserts',
#   'discount': 10,
#   'name': 'choco brownie fuj',
#   'pr': 500,
#   'qn': 20,
#   'ratings': 'Unrated'},
#  '1037': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 10,
#   'name': 'paneer pizza',
#   'pr': 400,
#   'qn': 20,
#   'ratings': 'Unrated'},
#  '1038': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 0,
#   'name': 'frooty',
#   'pr': 50,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1039': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 5,
#   'name': 'idli',
#   'pr': 100,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1040': {'Times_purchased': 0,
#   'category': 'Deserts',
#   'discount': 5,
#   'name': 'Donuts',
#   'pr': 250,
#   'qn': 20,
#   'ratings': 'Unrated'},
#  '1041': {'Times_purchased': 0,
#   'Times_rated': 0,
#   'category': 'Desserts',
#   'discount': 10,
#   'name': 'rabri',
#   'pr': 400,
#   'qn': 20,
#   'ratings': 'Unrated'}}

# %% [markdown]
# ###Deleting a record

# %%
del record['1001']

# %%
record
# Out:
# {'1002': {'Category': 'Beverages',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Cola',
#   'pr': 800,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1003': {'Category': 'Chinese',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Noodles',
#   'pr': 85,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1004': {'Category': 'Pizza',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'margherita',
#   'pr': 5,
#   'qn': 1000,
#   'ratings': 'Unrated'},
#  '1005': {'Category': 'Fastfood',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Sandwich',
#   'pr': 20,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1006': {'Category': 'Fastfood',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Burger',
#   'pr': 50000,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1007': {'Category': 'Pizza',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Cheese and corn pizza',
#   'pr': 1500,
#   'qn': 0,
#   'ratings': 'Unrated'},
#  '1008': {'Category': 'Deserts',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Icecream',
#   'pr': 599,
#   'qn': 5,
#   'ratings': 'Unrated'},
#  '1009': {'Category': 'Chinese',
#   'Times_purchased': 0,
#   'Times_rated': 0,
#   'discount': 10,
#   'name': 'Manchurian',
#   'pr': 1999,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1010': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 10,
#   'name': 'mojito',
#   'pr': 400,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1011': {'Times_purchased': 0,
#   'category': 'Chinese',
#   'discount': 25,
#   'name': 'whitw sause pasta',
#   'pr': 500,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1012': {'Times_purchased': 0,
#   'category': 'Deserts',
#   'discount': 23,
#   'name': 'Ras Malai',
#   'pr': 250,
#   'qn': 30,
#   'ratings': 'Unrated'},
#  '1013': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 10,
#   'name': 'Cheese Chutney Sandwich',
#   'pr': 200,
#   'qn': 60,
#   'ratings': 'Unrated'},
#  '1014': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 5,
#   'name': 'Pepsi',
#   'pr': 60,
#   'qn': 80,
#   'ratings': 'Unrated'},
#  '1015': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 20,
#   'name': 'Peppy Paneer',
#   'pr': 450,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1016': {'Times_purchased': 0,
#   'category': 'Deserts',
#   'discount': 10,
#   'name': 'Gulab Jaamun',
#   'pr': 300,
#   'qn': 20,
#   'ratings': 'Unrated'},
#  '1017': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 20,
#   'name': 'pav bhaji',
#   'pr': 400,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1018': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 0,
#   'name': 'kachori',
#   'pr': 20,
#   'qn': 100,
#   'ratings': 'Unrated'},
#  '1019': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 20,
#   'name': 'Mexican Pizza',
#   'pr': 600,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1020': {'Times_purchased': 0,
#   'category': 'Desserts',
#   'discount': 5,
#   'name': 'Cornetto Icecream',
#   'pr': 100,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1021': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 5,
#   'name': 'Cold Coffee',
#   'pr': 200,
#   'qn': 30,
#   'ratings': 'Unrated'},
#  '1023': {'Times_purchased': 0,
#   'category': 'Bevarages',
#   'discount': 0,
#   'name': 'Tea',
#   'pr': 20,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1024': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 15,
#   'name': 'Cheese burst Sandwich',
#   'pr': 500,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1025': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 10,
#   'name': 'Red sauce pasta',
#   'pr': 300,
#   'qn': 10,
#   'ratings': 'Unrated'},
#  '1026': {'Times_purchased': 0,
#   'category': 'Chinese',
#   'discount': 10,
#   'name': 'Sizzler',
#   'pr': 800,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1027': {'Times_purchased': 0,
#   'category': 'Pizza',
#   'discount': 10,
#   'name': 'Paneer and Onion Pizza',
#   'pr': 500,
#   'qn': 12,
#   'ratings': 'Unrated'},
#  '1028': {'Times_purchased': 0,
#   'category': 'Desserts',
#   'discount': 10,
#   'name': 'Bengalli sweet',
#   'pr': 480,
#   'qn': 50,
#   'ratings': 'Unrated'},
#  '1029': {'Times_purchased': 0,
#   'category': 'Chinese',
#   'discount': 15,
#   'name': 'chinese bhel',
#   'pr': 380,
#   'qn': 20,
#   'ratings': 'Unrated'},
#  '1030': {'Times_purchased': 0,
#   'category': 'Beverages',
#   'discount': 10,
#   'name': 'Kitkat shake',
#   'pr': 250,
#   'qn': 40,
#   'ratings': 'Unrated'},
#  '1031': {'Times_purchased': 0,
#   'category': 'Fastfood',
#   'discount': 0,
#   'name': 'Chinese pattis',
#   'pr': 25,
#   'qn': 25,
#   'ratings': 'Unrated'}}
